# %%
#pandas

# %%
import pandas as pd

# %%
import numpy as np

# %%
#lista

# %%
my_list= [10,20,30]

# %%
my_list
# Out:
# [10, 20, 30]

# %%
#obična lista

# %%
#numpy array

# %%
np.array(my_list)
# Out:
# array([10, 20, 30])

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
#ima indexe, ima vrijednosti, može i ne mora imati ime cijele serije

# %%
#pd series je lakše raditi, lakše se filtriraju, analiziraju

# %%
#mogućnost dodijeljivanja indexa

# %%
ind=['a', 'b', 'c']
pd.Series(data=my_list, index=ind, name= 'heather')
# Out:
# a    10
# b    20
# c    30
# Name: heather, dtype: int64

# %%
#rječnik u pd series, ključevi će postati indeksi

# %%
#rječnik

# %%
d ={'a': 1, 'b':2 }
d
# Out:
# {'a': 1, 'b': 2}

# %%
pd.Series(d, name=' heather')
# Out:
# a    1
# b    2
# Name:  heather, dtype: int64

# %%
#možemo sve i u jednom redu

# %%
tab1= pd.Series(data=[1,2,3,4], index= ['A', 'B', 'C', 'D'], name='Data set')
tab1
# Out:
# A    1
# B    2
# C    3
# D    4
# Name: Data set, dtype: int64

# %%
#izdvajanje vrijednosti iz pd series

# %%
#pomoću lokacije, broj retka

# %%
tab1[0]
# Out:
# /tmp/ipython-input-2311236939.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tab1[0]
# np.int64(1)

# %%
tab1[[0,1]]
# Out:
# /tmp/ipython-input-813333662.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tab1[[0,1]]
# A    1
# B    2
# Name: Data set, dtype: int64

# %%
#pomoću indexa

# %%
tab1['B']
# Out:
# np.int64(2)

# %%
tab1[['B', 'C']]
# Out:
# B    2
# C    3
# Name: Data set, dtype: int64

# %%
#više stvari, dupla zagrada!!!

# %%
#zbrajanje/adicija pd series

# %%
tab2= pd.Series([2,4,5,6,], ['A', 'E', 'C', 'F'])
tab2
# Out:
# A    2
# E    4
# C    5
# F    6
# dtype: int64

# %%
tab1
# Out:
# A    1
# B    2
# C    3
# D    4
# Name: Data set, dtype: int64

# %%
tab1 + tab2
# Out:
# A    3.0
# B    NaN
# C    8.0
# D    NaN
# E    NaN
# F    NaN
# dtype: float64

# %%
#data frame

# %%
np.random.randn(5,4)
# Out:
# array([[ 0.29984996, -0.38182075,  0.4118207 , -0.4735736 ],
#        [ 0.38432271, -0.04982165, -1.00549459,  2.85757525],
#        [-0.02222046, -1.24351052, -0.26779111, -0.281704  ],
#        [-0.1919848 ,  2.39509915,  0.64352845, -1.12863448],
#        [ 1.04883928,  0.56815693,  1.77867152,  0.9179937 ]])
# array([[-3.62976249e-01, -7.78240003e-01,  1.21432948e+00,
#         -4.25422909e-01],
#        [-1.59214512e+00, -1.93638438e+00, -6.19135595e-01,
#          6.31160579e-01],
#        [ 1.26214404e+00, -1.89579588e+00,  9.48920057e-01,
#         -5.00388493e-01],
#        [ 7.93773639e-01, -3.18020130e-01,  4.78162012e-01,
#         -5.64851912e-01],
#        [-6.13860275e-01,  1.83710926e-05, -7.30890811e-01,
#          1.15440569e+00]])

# %%
from numpy.random import randn

# %%
randn(5,4)
# Out:
# array([[ 0.56290695, -0.29062405,  1.10062236,  1.15371761],
#        [ 0.34481956,  0.19232826,  1.25210555, -0.97164011],
#        [ 0.25085564,  0.83527597,  1.6185953 ,  2.00833469],
#        [ 0.28180355,  1.1639203 , -0.63653524,  0.29564788],
#        [-0.05492477, -0.55816844,  0.18713907, -0.05353774]])

# %%
df= pd.DataFrame(randn(5,4),
                index= ['a', 'b', 'c', 'd', 'e'],
                 columns=['w', 'x', 'y', 'z'])
df
# Out:
#           w         x         y         z
# a -1.446818  0.961652  0.214771 -0.664635
# b -1.410294 -0.939869  0.650498  0.429821
# c  0.971547 -1.404626  1.146346 -0.015019
# d  1.120851  0.572744 -1.286729  0.967230
# e -1.343122 -1.591598  1.105562 -1.162090

# %%
#preimenujmo kolone u brojeve 1,2,3,4

# %%
df.columns=[1,2,3,4,]
df
# Out:
#           1         2         3         4
# a -1.446818  0.961652  0.214771 -0.664635
# b -1.410294 -0.939869  0.650498  0.429821
# c  0.971547 -1.404626  1.146346 -0.015019
# d  1.120851  0.572744 -1.286729  0.967230
# e -1.343122 -1.591598  1.105562 -1.162090

# %%
#vratimo na izvorno

# %%
df.columns=['w', 'x', 'y' , 'z']
df
# Out:
#           w         x         y         z
# a -1.446818  0.961652  0.214771 -0.664635
# b -1.410294 -0.939869  0.650498  0.429821
# c  0.971547 -1.404626  1.146346 -0.015019
# d  1.120851  0.572744 -1.286729  0.967230
# e -1.343122 -1.591598  1.105562 -1.162090

# %%
import matplotlib.pyplot as plt
plt.imshow(df)

# %%
#dohvaćanje vrijednosti .loc i .iloc

# %%
#.loc- prema oznakama redova , .iloc- prema poziciji

# %%
#dohvatimo sve vrijednosti iz prvog reda, index a pomoću .loc

# %%
df
# Out:
#           w         x         y         z
# a -1.446818  0.961652  0.214771 -0.664635
# b -1.410294 -0.939869  0.650498  0.429821
# c  0.971547 -1.404626  1.146346 -0.015019
# d  1.120851  0.572744 -1.286729  0.967230
# e -1.343122 -1.591598  1.105562 -1.162090

# %%
df.loc['a']
# Out:
# w   -1.446818
# x    0.961652
# y    0.214771
# z   -0.664635
# Name: a, dtype: float64

# %%
#kojeg je tipa

# %%
type(df.loc['a'])
# Out:
# pandas.core.series.Series

# %%
#jedna pandas serija

# %%
#sve vrijednosti 1 i 3 stupca pomoću .iloc

# %%
df.iloc[:, [0,2]]
# Out:
#           w         y
# a -1.446818  0.214771
# b -1.410294  0.650498
# c  0.971547  1.146346
# d  1.120851 -1.286729
# e -1.343122  1.105562

# %%
#vrijesnosti koje se nalaze u retku c i stupcima y i z, te vrijednosti iz retka d i stupca y i z

# %%
# 1 nacin

# %%
df.iloc[2:4, 2:]
# Out:
#           y         z
# c  1.146346 -0.015019
# d -1.286729  0.967230

# %%
#način

# %%
df[['y', 'z']].loc[['c', 'd']]
# Out:
#           y         z
# c  1.146346 -0.015019
# d -1.286729  0.967230

# %%
#izolirajmo vrijenosti iz stupca w i x, te retka b, od njih data frame koji se zove a

# %%
df
# Out:
#           w         x         y         z
# a -1.446818  0.961652  0.214771 -0.664635
# b -1.410294 -0.939869  0.650498  0.429821
# c  0.971547 -1.404626  1.146346 -0.015019
# d  1.120851  0.572744 -1.286729  0.967230
# e -1.343122 -1.591598  1.105562 -1.162090

# %%
plt.scatter(df['y'], df['z'])

# %%
#st dev iz retka c

# %%
df.loc['c'].std()
# Out:
# 1.1703736581521975

# %%
#varijanca stupca x

# %%
df['x'].var()
# Out:
# 1.3721734853041074

# %%
#izračunajmo st dev iz retka c i zaokružimo na 3 decimale

# %%
round(df.loc['c'].std(), 3)
# Out:
# 1.17

# %%
#od najvećeg u w oduzmimo najmanji iz z

# %%
df['w'].max() - df['z']
# Out:
# a    1.785486
# b    0.691030
# c    1.135870
# d    0.153621
# e    2.282941
# Name: z, dtype: float64

# %%
#je li st dev vrijednosti iz stupca x veća od st dev iz retka d

# %%
df.loc['c'].max() > df['z'].std()
# Out:
# True

# %%
# je li najveća vrijednost iz retka c veća od variance izračunate iz stupca 2

# %%
df.loc['c'].max()  >  df['z'].var()
# Out:
# True

# %%
#create column

# %%
#kreiramo kolonu koja će sadržati razliku vrijednosti kolona w i y

# %%
df['w'] - df['y']
# Out:
# a   -1.661589
# b   -2.060792
# c   -0.174799
# d    2.407580
# e   -2.448684
# dtype: float64

# %%
#dodijelimo naziv

# %%
df['wminy'] = df['w'] - df['y']

# %%
df
# Out:
#           w         x         y         z     wminy
# a -1.446818  0.961652  0.214771 -0.664635 -1.661589
# b -1.410294 -0.939869  0.650498  0.429821 -2.060792
# c  0.971547 -1.404626  1.146346 -0.015019 -0.174799
# d  1.120851  0.572744 -1.286729  0.967230  2.407580
# e -1.343122 -1.591598  1.105562 -1.162090 -2.448684

# %%
df['logx'] = np.log10(df['x'])
df
# Out:
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#           w         x         y         z     wminy      logx
# a -1.446818  0.961652  0.214771 -0.664635 -1.661589 -0.016982
# b -1.410294 -0.939869  0.650498  0.429821 -2.060792       NaN
# c  0.971547 -1.404626  1.146346 -0.015019 -0.174799       NaN
# d  1.120851  0.572744 -1.286729  0.967230  2.407580 -0.242039
# e -1.343122 -1.591598  1.105562 -1.162090 -2.448684       NaN

# %%
#dodajemo kolonu koja ima log vrijednosti

# %%
#def funkciju koja će izračunati ph vrijednost pomoću konc

# %%
def ph(c):
  return -np.log10(c)

# %%
#primjenimo na kolonu x to

# %%
#apply() na svaki element seriesa, kolonu/redak

# %%
df['x'].apply(ph)
# Out:
# /tmp/ipython-input-3949198537.py:2: RuntimeWarning: invalid value encountered in log10
#   return -np.log10(c)
# a    0.016982
# b         NaN
# c         NaN
# d    0.242039
# e         NaN
# Name: x, dtype: float64

# %%
#slično ali sam lambda

# %%
df['x'].apply(lambda x: -np.log10(x))
# Out:
# /tmp/ipython-input-2045124174.py:1: RuntimeWarning: invalid value encountered in log10
#   df['x'].apply(lambda x: -np.log10(x))
# a    0.016982
# b         NaN
# c         NaN
# d    0.242039
# e         NaN
# Name: x, dtype: float64

# %%
df
# Out:
#           w         x         y         z     wminy      logx
# a -1.446818  0.961652  0.214771 -0.664635 -1.661589 -0.016982
# b -1.410294 -0.939869  0.650498  0.429821 -2.060792       NaN
# c  0.971547 -1.404626  1.146346 -0.015019 -0.174799       NaN
# d  1.120851  0.572744 -1.286729  0.967230  2.407580 -0.242039
# e -1.343122 -1.591598  1.105562 -1.162090 -2.448684       NaN

# %%
#sve vrijednosti iz df pomnoži sa 2 i dodaj 100

# %%
df.applymap(lambda x: 2*x+100)
# Out:
# /tmp/ipython-input-777182660.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: 2*x+100)
#             w           x           y           z       wminy       logx
# a   97.106364  101.923304  100.429542   98.670730   96.676821  99.966036
# b   97.179411   98.120261  101.300995  100.859642   95.878416        NaN
# c  101.943093   97.190748  102.292692   99.969962   99.650402        NaN
# d  102.241702  101.145489   97.426541  101.934461  104.815161  99.515922
# e   97.313756   96.816804  102.211124   97.675820   95.102632        NaN

# %%
#apply map- na cijeli df se primjeni

# %%
#drugi način

# %%
def fun(x):
  return 2*x+100

# %%
df.applymap(fun)
# Out:
# /tmp/ipython-input-29085701.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(fun)
#             w           x           y           z       wminy       logx
# a   97.106364  101.923304  100.429542   98.670730   96.676821  99.966036
# b   97.179411   98.120261  101.300995  100.859642   95.878416        NaN
# c  101.943093   97.190748  102.292692   99.969962   99.650402        NaN
# d  102.241702  101.145489   97.426541  101.934461  104.815161  99.515922
# e   97.313756   96.816804  102.211124   97.675820   95.102632        NaN

# %%
#kvadriramo sve vrijednosti u df

# %%
df.applymap(lambda x: x**2)
# Out:
# /tmp/ipython-input-1911323247.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: x**2)
#           w         x         y         z     wminy      logx
# a  2.093283  0.924774  0.046127  0.441740  2.760879  0.000288
# b  1.988930  0.883355  0.423147  0.184746  4.246864       NaN
# c  0.943903  1.972974  1.314109  0.000226  0.030555       NaN
# d  1.256307  0.328036  1.655672  0.935535  5.796444  0.058583
# e  1.803977  2.533185  1.222267  1.350453  5.996052       NaN

# %%
#def funk koja će odrediti jesu li vrijednosti iznad lod( limit od detection)

# %%
#lod- 0.01

# %%
def above_lod(x):
  if x > 0.01:
    return 'above lod'
  else:
    return 'xxx'

# %%
above_lod(0.01)
# Out:
# 'xxx'

# %%
above_lod(.02)
# Out:
# 'above lod'

# %%
#primjenimo above_lod funk na df

# %%
df.applymap(above_lod)
# Out:
# /tmp/ipython-input-828190318.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(above_lod)
#            w          x          y          z      wminy logx
# a        xxx  above lod  above lod        xxx        xxx  xxx
# b        xxx        xxx  above lod  above lod        xxx  xxx
# c  above lod        xxx  above lod        xxx        xxx  xxx
# d  above lod  above lod        xxx  above lod  above lod  xxx
# e        xxx        xxx  above lod        xxx        xxx  xxx

# %%
df
# Out:
#           w         x         y         z     wminy      logx
# a -1.446818  0.961652  0.214771 -0.664635 -1.661589 -0.016982
# b -1.410294 -0.939869  0.650498  0.429821 -2.060792       NaN
# c  0.971547 -1.404626  1.146346 -0.015019 -0.174799       NaN
# d  1.120851  0.572744 -1.286729  0.967230  2.407580 -0.242039
# e -1.343122 -1.591598  1.105562 -1.162090 -2.448684       NaN

# %%
#df = df.applymap(above_lod)- inače se neće spremiti i bit će stari df bez promijena, python sam ne sprema info

# %%
#stvorimo novi stupac u df above_lod na temelju vrijednosti iz stupca x, ako je vrijednosti > od 0.01 ta vrijednosrti, ako ne 0.0001

# %%
plt.imshow(np.log10(abs(df.iloc[:, :-1])))

# %%
#sve retke, i svi stupci osim zadnjeg, log10 od abs vrijednosti i heat map

# %%
df['above_lod']= df['x'].apply(lambda x: x if x > 0.01 else 0.001)
df
# Out:
#           w         x         y         z     wminy      logx  above_lod
# a -1.446818  0.961652  0.214771 -0.664635 -1.661589 -0.016982   0.961652
# b -1.410294 -0.939869  0.650498  0.429821 -2.060792       NaN   0.001000
# c  0.971547 -1.404626  1.146346 -0.015019 -0.174799       NaN   0.001000
# d  1.120851  0.572744 -1.286729  0.967230  2.407580 -0.242039   0.572744
# e -1.343122 -1.591598  1.105562 -1.162090 -2.448684       NaN   0.001000

# %%
#primjenimo stupd alove lod, ako je x > 0.01, taj x, ako nije da piše <lod, ne dodajemo već mijenjamo ovaj koji je već

# %%
df ['above lod'] = df ['x'].apply(lambda x: x if x >=0.01 else '<lod')

# %%
df
# Out:
#           w         x         y         z above lod
# a -1.446818  0.961652  0.214771 -0.664635  0.961652
# b -1.410294 -0.939869  0.650498  0.429821      <lod
# c  0.971547 -1.404626  1.146346 -0.015019      <lod
# d  1.120851  0.572744 -1.286729  0.967230  0.572744
# e -1.343122 -1.591598  1.105562 -1.162090      <lod

# %%
df['positive_nmb']= df ['w'].apply(lambda x : 'p' if x>= 0 else 'n')

# %%
df
# Out:
#           w         x         y         z
# a -1.446818  0.961652  0.214771 -0.664635
# b -1.410294 -0.939869  0.650498  0.429821
# c  0.971547 -1.404626  1.146346 -0.015019
# d  1.120851  0.572744 -1.286729  0.967230
# e -1.343122 -1.591598  1.105562 -1.162090

# %%
#novi stupac na temelju vrijednosti iz w, veća ili jednaka 0 p, nije n

# %%
#drop a column, axis=0 vertikalno- briše redak, axis=1 horizontalno, briše stupac

# %%
#izbaci wimy, logx, above lod i positive_nmb

# %%
df.drop([ 'above lod'], axis=1, inplace=True)
df
# Out:
#           w         x         y         z
# a -1.446818  0.961652  0.214771 -0.664635
# b -1.410294 -0.939869  0.650498  0.429821
# c  0.971547 -1.404626  1.146346 -0.015019
# d  1.120851  0.572744 -1.286729  0.967230
# e -1.343122 -1.591598  1.105562 -1.162090

# %%
#izbaci redak b ali nemoj inplace= true

# %%
df.drop(['b'], axis=0)
# Out:
#           w         x         y         z
# a -1.446818  0.961652  0.214771 -0.664635
# c  0.971547 -1.404626  1.146346 -0.015019
# d  1.120851  0.572744 -1.286729  0.967230
# e -1.343122 -1.591598  1.105562 -1.162090

# %%
#shape of data frame

# %%
#boolean

# %%
#nije jednako !=, jesu li vrijednosti različite od 0

# %%
#jesu li veće od 0

# %%
b_df= df[['w', 'x', 'y']] >0
b_df
# Out:
#        w      x      y
# a  False   True   True
# b  False  False   True
# c   True  False   True
# d   True   True  False
# e  False  False   True

# %%
#samo pozitivne vrijednosti

# %%
df[b_df]
# Out:
#           w         x         y   z
# a       NaN  0.961652  0.214771 NaN
# b       NaN       NaN  0.650498 NaN
# c  0.971547       NaN  1.146346 NaN
# d  1.120851  0.572744       NaN NaN
# e       NaN       NaN  1.105562 NaN

# %%
#primjeni masku na df, izbriši sve retke i stupce koji imamju nan, ostale nan se mijenjaju sa 0.001

# %%
df[b_df].dropna(how='all', axis=0).dropna(how='all', axis=1).dropna(how='any', axis=0).dropna(how='any', axis=1)
# Out:
# Empty DataFrame
# Columns: [w, x, y]
# Index: []

# %%
#any- di ima barem jedan, all- cijeli redak/stupac- to je kod how

# %%
#popuni stupca z 0, na cijeli primjeni if else funk, ako je veća od 0.01 v, ako ne 0.001

# %%
df
# Out:
#           w         x         y         z
# a -1.446818  0.961652  0.214771 -0.664635
# b -1.410294 -0.939869  0.650498  0.429821
# c  0.971547 -1.404626  1.146346 -0.015019
# d  1.120851  0.572744 -1.286729  0.967230
# e -1.343122 -1.591598  1.105562 -1.162090

# %%
df['z'] = 0
df = df.applymap(lambda x: x if x > 0.01 else 0.001)
# Out:
# /tmp/ipython-input-909537063.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x if x > 0.01 else 0.001)

# %%
df
# Out:
#           w         x         y      z
# a  0.001000  0.961652  0.214771  0.001
# b  0.001000  0.001000  0.650498  0.001
# c  0.971547  0.001000  1.146346  0.001
# d  1.120851  0.572744  0.001000  0.001
# e  0.001000  0.001000  1.105562  0.001

# %%
df.drop('z', axis=1)
df.replace(0.001, np.nan).dropna(how='all', axis=0).replace(np.nan, 0.001)
# Out:
#           w         x         y      z
# a  0.001000  0.961652  0.214771  0.001
# b  0.001000  0.001000  0.650498  0.001
# c  0.971547  0.001000  1.146346  0.001
# d  1.120851  0.572744  0.001000  0.001
# e  0.001000  0.001000  1.105562  0.001

# %%
#mičemo z, zamijeno 0.001 sa nan, ostale nan zamijeni sa 0.001

# %%
#ponovno stvaramo df

# %%
df= pd.DataFrame(randn(5,4),
                 ['a', 'b', 'c', 'd', 'e'],
                 ['w', 'x', 'y', 'z'])

# %%
df
# Out:
#           w         x         y         z
# a  0.956236  1.141963  1.803876 -0.573343
# b -0.020489 -0.151803  0.555995 -1.099617
# c -2.461722 -1.895818 -1.031891  0.082319
# d -1.772787 -0.525344 -0.231121 -0.910774
# e -0.841130  1.080273  0.408200  0.452934

# %%
#koje su vrijednosti iznad lod, 0.001, prebroji vrijednosti po stupcima

# %%
lod = 0.001
df[df > lod].count(axis=1)
# Out:
# a    3
# b    1
# c    1
# d    0
# e    3
# dtype: int64

# %%
#ostavi retke koji u stupcu w imaju > -0.1
#ispiši samo vrijednosti stupca x iz tih preostalih redaka

# %%
df[df['w'] > -0.1]['x']
# Out:
# a    1.141963
# b   -0.151803
# Name: x, dtype: float64

# %%
#ostavti retke iz df koji u w ili y > 0, korisiti se |

# %%
df[(df['w']> 0 )| (df['y']> 0)]
# Out:
#           w         x         y         z
# a  0.956236  1.141963  1.803876 -0.573343
# b -0.020489 -0.151803  0.555995 -1.099617
# e -0.841130  1.080273  0.408200  0.452934

# %%
#ako imamo i, jedne i druge

# %%
df[(df['w']> 0 )& (df['y']> 0)]
# Out:
#           w         x         y         z
# a  0.956236  1.141963  1.803876 -0.573343

# %%
#reset index

# %%
df
# Out:
#           w         x         y         z
# a  0.956236  1.141963  1.803876 -0.573343
# b -0.020489 -0.151803  0.555995 -1.099617
# c -2.461722 -1.895818 -1.031891  0.082319
# d -1.772787 -0.525344 -0.231121 -0.910774
# e -0.841130  1.080273  0.408200  0.452934

# %%
df.reset_index(drop=False)
# Out:
#   index         w         x         y         z
# 0     a  0.956236  1.141963  1.803876 -0.573343
# 1     b -0.020489 -0.151803  0.555995 -1.099617
# 2     c -2.461722 -1.895818 -1.031891  0.082319
# 3     d -1.772787 -0.525344 -0.231121 -0.910774
# 4     e -0.841130  1.080273  0.408200  0.452934

# %%
#drop false- novi stupac, nije izbačeno, da je drop true maknulo bi se a,b..

# %%
#in place= true, ostaje u memoriji, inače ne

# %%
df
# Out:
#           w         x         y         z
# a  0.956236  1.141963  1.803876 -0.573343
# b -0.020489 -0.151803  0.555995 -1.099617
# c -2.461722 -1.895818 -1.031891  0.082319
# d -1.772787 -0.525344 -0.231121 -0.910774
# e -0.841130  1.080273  0.408200  0.452934

# %%
#kako to nismo koristili, df je ostao isti ko i prije

# %%
#set index

# %%
#mijenjamo nazive kolona, stavimo nove

# %%
old_cols = df.columns.tolist()
old_cols
# Out:
# ['w', 'x', 'y', 'z']

# %%
new_cols = ['A', 'B', 'C', 'D']

# %%
df.columns = new_cols
df
# Out:
#           A         B         C         D
# a  0.956236  1.141963  1.803876 -0.573343
# b -0.020489 -0.151803  0.555995 -1.099617
# c -2.461722 -1.895818 -1.031891  0.082319
# d -1.772787 -0.525344 -0.231121 -0.910774
# e -0.841130  1.080273  0.408200  0.452934

# %%
df
# Out:
#           A         B         C         D
# a  0.956236  1.141963  1.803876 -0.573343
# b -0.020489 -0.151803  0.555995 -1.099617
# c -2.461722 -1.895818 -1.031891  0.082319
# d -1.772787 -0.525344 -0.231121 -0.910774
# e -0.841130  1.080273  0.408200  0.452934

# %%
#missing data

# %%
#pišu se kao nan ili none, null vrijednosti

# %%
#kreiramo df sa nedostajućim vrijed

# %%
d = {'a': [1,2, np.nan], 'b': [5, np.nan, np.nan], 'c':[1,2,3]}

# %%
d
# Out:
# {'a': [1, 2, nan], 'b': [5, nan, nan], 'c': [1, 2, 3]}

# %%
df = pd.DataFrame(d)
#jednako bi bilo da je (data=d)

# %%
df
# Out:
#      a    b  c
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
#drop rows with null values

# %%
#any ide po defaultu, ako ne napišemo how='any', ide svejedno any

# %%
df.dropna(how='any', axis=0)
# Out:
#      a    b  c
# 0  1.0  5.0  1

# %%
#drop columns with null

# %%
df.dropna(how='all', axis=1)
# Out:
#      a    b  c
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
#drop rows with null adding threshold

# %%
#retke koji imaji barem 3 nan vr

# %%
df.dropna(thresh=2, axis=0)
# Out:
#      a    b  c
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
#thresh, nema how onda, po def idu retci, axis=0, ali svejedno pišemo

# %%
#fill missing values

# %%
#provjerimo srednju vrijednosti po stupcima

# %%
df.mean(axis=0)
# Out:
# a    1.5
# b    5.0
# c    2.0
# dtype: float64

# %%
df
# Out:
#      a    b  c
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
#mijenjamo nan

# %%
df.fillna(value='xxx')
# Out:
#      a    b  c
# 0  1.0  5.0  1
# 1  2.0  xxx  2
# 2  xxx  xxx  3

# %%
#ili neku funk

# %%
df.fillna(value=df.mean())
# Out:
#      a    b  c
# 0  1.0  5.0  1
# 1  2.0  5.0  2
# 2  1.5  5.0  3

# %%
#group by

# %%
data= {'chemist': ['t', 'i', 't', 'i', 't', 't'],
       'lokacija': ['zg', 'zd', 'zg', 'zg', 'zd', 'zg' ],
       'konc': ['1', '2', '3', '4', '5', '6']}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   chemist lokacija konc
# 0       t       zg    1
# 1       i       zd    2
# 2       t       zg    3
# 3       i       zg    4
# 4       t       zd    5
# 5       t       zg    6

# %%
#koje se vrijednosti ponavljalju u stupcu lokacija?

# %%
df['lokacija'].unique()
# Out:
# array(['zg', 'zd'], dtype=object)

# %%
#jedinstvene lok, koje sve postoje

# %%
#group by dijeli ih prema nekom kriteriju, a zatim na svakoj grupi radi neku operaciju zasebno

# %%
#želimo provjeriti koja je  st dev izmjerenih konc prema gradu

# %%
df.groupby('lokacija')['konc'].std()
#(nešto od čega želimo napraviti grupe)[numerički].operacija()
# Out:
# lokacija
# zd    2.121320
# zg    2.081666
# Name: konc, dtype: float64

# %%
#brza stat analiza- računa se stat svih num varijabli

# %%
df.describe()
# Out:
#        chemist lokacija konc
# count        6        6    6
# unique       2        2    6
# top          t       zg    1
# freq         4        4    1

# %%
#konc, spajanje

# %%
#opet df sa random br

# %%
df = pd.DataFrame(randn(5,4),
                  ['a', 'b', 'c', 'd', 'e'],
                  ['w', 'x', 'y',' z'])

# %%
#drugi df koji ima abs vrijednosti prvog df, preimenovanje indexe

# %%
df2= np.abs(df)
df2.index=['a1', 'b1', 'c1', 'd1', 'e1']
df2
# Out:
#            w         x         y         z
# a1  0.029443  0.652287  0.540177  0.394841
# b1  1.031011  0.784375  0.367944  0.591833
# c1  1.468032  0.363806  0.066000  0.319290
# d1  1.019488  0.735247  1.230297  1.679584
# e1  1.248657  0.603942  0.990140  1.047333

# %%
df
# Out:
#           w         x         y         z
# a -0.029443 -0.652287 -0.540177 -0.394841
# b  1.031011  0.784375 -0.367944  0.591833
# c -1.468032  0.363806  0.066000  0.319290
# d -1.019488  0.735247  1.230297  1.679584
# e -1.248657  0.603942  0.990140  1.047333

# %%
#provjera shapea, jesu li iste veličine

# %%
df.shape
# Out:
# (5, 4)

# %%
df2.shape
# Out:
# (5, 4)

# %%
#spajanje df i df2

# %%
df3 = pd.concat([df, df2], axis=1)
df3
# Out:
#            w         x         y         z         w         x         y  \
# a  -0.029443 -0.652287 -0.540177 -0.394841       NaN       NaN       NaN
# b   1.031011  0.784375 -0.367944  0.591833       NaN       NaN       NaN
# c  -1.468032  0.363806  0.066000  0.319290       NaN       NaN       NaN
# d  -1.019488  0.735247  1.230297  1.679584       NaN       NaN       NaN
# e  -1.248657  0.603942  0.990140  1.047333       NaN       NaN       NaN
# a1       NaN       NaN       NaN       NaN  0.029443  0.652287  0.540177
# b1       NaN       NaN       NaN       NaN  1.031011  0.784375  0.367944
# c1       NaN       NaN       NaN       NaN  1.468032  0.363806  0.066000
# d1       NaN       NaN       NaN       NaN  1.019488  0.735247  1.230297
# e1       NaN       NaN       NaN       NaN  1.248657  0.603942  0.990140
#
#            z
# a        NaN
# b        NaN
# c        NaN
# d        NaN
# e        NaN
# a1  0.394841
# b1  0.591833
# c1  0.319290
# d1  1.679584
# e1  1.047333

# %%
#spajanje po stupcima, jedan do drugoga se spajaju, duplanje

# %%
df4 = pd.concat([df, df2], axis=0)
df4
# Out:
#            w         x         y         z
# a  -0.029443 -0.652287 -0.540177 -0.394841
# b   1.031011  0.784375 -0.367944  0.591833
# c  -1.468032  0.363806  0.066000  0.319290
# d  -1.019488  0.735247  1.230297  1.679584
# e  -1.248657  0.603942  0.990140  1.047333
# a1  0.029443  0.652287  0.540177  0.394841
# b1  1.031011  0.784375  0.367944  0.591833
# c1  1.468032  0.363806  0.066000  0.319290
# d1  1.019488  0.735247  1.230297  1.679584
# e1  1.248657  0.603942  0.990140  1.047333

# %%
#vertikalno spajanje, iste vrijednosti idu u istu kolonu, nema duplanja

# %%
df4.describe()
# Out:
#                w          x          y          z
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.206202   0.497474   0.457287   0.727608
# std     1.116032   0.432309   0.646354   0.646177
# min    -1.468032  -0.652287  -0.540177  -0.394841
# 25%    -0.771977   0.423840   0.066000   0.338178
# 50%     0.524466   0.628115   0.454060   0.591833
# 75%     1.031011   0.735247   0.990140   1.047333
# max     1.468032   0.784375   1.230297   1.679584

# %%
#sort, po porastu ili padu vrijednosti

# %%
df2
# Out:
#            w         x         y         z
# a1  0.029443  0.652287  0.540177  0.394841
# b1  1.031011  0.784375  0.367944  0.591833
# c1  1.468032  0.363806  0.066000  0.319290
# d1  1.019488  0.735247  1.230297  1.679584
# e1  1.248657  0.603942  0.990140  1.047333

# %%
df2.sort_values(by='w', ascending=True)
# Out:
#            w         x         y         z
# a1  0.029443  0.652287  0.540177  0.394841
# d1  1.019488  0.735247  1.230297  1.679584
# b1  1.031011  0.784375  0.367944  0.591833
# e1  1.248657  0.603942  0.990140  1.047333
# c1  1.468032  0.363806  0.066000  0.319290

# %%
#input and output

# %%
df
# Out:
#           w         x         y         z
# a -0.029443 -0.652287 -0.540177 -0.394841
# b  1.031011  0.784375 -0.367944  0.591833
# c -1.468032  0.363806  0.066000  0.319290
# d -1.019488  0.735247  1.230297  1.679584
# e -1.248657  0.603942  0.990140  1.047333

# %%
#to csv

# %%
df.to_csv('datoteka1.csv')

# %%
#read csv

# %%
pozvana = pd.read_csv('datoteka1.csv')
pozvana
# Out:
#   Unnamed: 0         w         x         y         z
# 0          a -0.029443 -0.652287 -0.540177 -0.394841
# 1          b  1.031011  0.784375 -0.367944  0.591833
# 2          c -1.468032  0.363806  0.066000  0.319290
# 3          d -1.019488  0.735247  1.230297  1.679584
# 4          e -1.248657  0.603942  0.990140  1.047333

# %%
#indexi prijeđu u novi stupac, dodajemo index_col=0

# %%
pozvana = pd.read_csv('datoteka1.csv', index_col=0)
pozvana
# Out:
#           w         x         y         z
# a -0.029443 -0.652287 -0.540177 -0.394841
# b  1.031011  0.784375 -0.367944  0.591833
# c -1.468032  0.363806  0.066000  0.319290
# d -1.019488  0.735247  1.230297  1.679584
# e -1.248657  0.603942  0.990140  1.047333

# %%
#excel

# %%
#read excel

# %%
df.to_excel('datoteka2.xlsx')

# %%
excel_dat= pd.read_excel('datoteka2.xlsx', index_col=0)
excel_dat
# Out:
#           w         x         y         z
# a -0.029443 -0.652287 -0.540177 -0.394841
# b  1.031011  0.784375 -0.367944  0.591833
# c -1.468032  0.363806  0.066000  0.319290
# d -1.019488  0.735247  1.230297  1.679584
# e -1.248657  0.603942  0.990140  1.047333

# %%
#cluster map

# %%
import seaborn as sns

# %%
# za vizualizaciju, na matplotlim, statistika, estetski lijepša

# %%
sns.clustermap(pozvana, figsize=(5,5), cmap='vlag')
